# %%
from dataset.synthetic_card_image_dataset import SyntheticCardImageDataset

dataset = SyntheticCardImageDataset(672, to_tensor=False, hardness=1)

# %%
img, img_gt = dataset[0]
img
# Out:
# <PIL.Image.Image image mode=L size=672x672 at 0x7F53E90466A0>

# %%
img_gt
# Out:
# <PIL.Image.Image image mode=L size=672x672 at 0x7F53E9046470>
