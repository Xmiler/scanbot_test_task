# %%
from dataset.synthetic_card_image_dataset import SyntheticCardImageDataset

dataset = SyntheticCardImageDataset(to_tensor=False)

# %%
img, img_gt = dataset[0]
img
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F3F6C998390>

# %%
img_gt
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F3F6C998320>
