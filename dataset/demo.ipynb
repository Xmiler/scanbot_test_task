# %%
from synthetic_card_image_dataset import SyntheticCardImageDataset

# %%
dataset = SyntheticCardImageDataset()

# %%
img, img_gt = dataset[100000000]
img
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F33246109B0>

# %%
img_gt
# Out:
# <PIL.Image.Image image mode=L size=800x800 at 0x7F3324610518>

# %%
from torchvision import transforms

# %%
# Out:
# <module 'torchvision.transforms' from '/home/xmiler/.virtualenvs/torch/lib/python3.6/site-packages/torchvision/transforms/__init__.py'>

# %%
w, h = img.size
size = max(w, h)
x1_pad = ((size - w) / 2)
x2_pad = size - w - x1_pad
y1_pad = ((size - h) / 2)
y2_pad = size - h - y1_pad

# %%
transforms.Pad((x1_pad, y1_pad, x2_pad, y2_pad))
# Out:
# Pad(padding=(0.0, 75.0, 0.0, 75.0), fill=0, padding_mode=constant)
