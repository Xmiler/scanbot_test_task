# %%
from synthetic_card_image_dataset import SyntheticCardImageDataset

dataset = SyntheticCardImageDataset(to_tensor=False)

# %%
img, img_gt = dataset[0]
img
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FAE4B5E46D8>

# %%
img_gt
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FAE4B5E4668>
